# %% [markdown]
# # *Exploratory Data Analysis (EDA) for Employee Attrition Dataset*

# %% [markdown]
# ---

# %% [markdown]
# ### 1. Load and Review the Dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv(r'Raw Data\Employees_Attirition.csv')

# %%
# Overview of the dataset
df.head()
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0  41.0       Yes      Travel_Rarely       1102                   Sales
# 1  49.0        No  Travel_Frequently        279  Research & Development
# 2  37.0       Yes      Travel_Rarely       1373  Research & Development
# 3  33.0        No  Travel_Frequently       1392  Research & Development
# 4  27.0        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1323 non-null   float64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe(include='all')
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1323.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.900227       NaN            NaN   802.485714
# std        9.155937       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Data Cleaning

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Age                         147
# Attrition                     0
# BusinessTravel                0
# DailyRate                     0
# Department                    0
# DistanceFromHome              0
# Education                     0
# EducationField                0
# EmployeeCount                 0
# EmployeeNumber                0
# EnvironmentSatisfaction       0
# Gender                        0
# HourlyRate                    0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction             294
# MaritalStatus                 0
# MonthlyIncome               220
# MonthlyRate                   0
# NumCompaniesWorked            0
# Over18                        0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# StandardHours                 0
# StockOptionLevel              0
# TotalWorkingYears             0
# ...

# %%
# Visualize missing data
sns.heatmap(df.isnull(), cbar=True, cmap="viridis")
plt.title("Missing Data Heatmap")
plt.show()

# %%
# Handle missing values
df['Age'].fillna(df['Age'].median(), inplace=True)
df['JobSatisfaction'].fillna(df['JobSatisfaction'].mode()[0], inplace=True)
df['MonthlyIncome'].fillna(df['MonthlyIncome'].mean(), inplace=True)
df.dropna(inplace=True)
# Out:
# C:\Users\elkfrawy\AppData\Local\Temp\ipykernel_8232\2317360568.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)
# C:\Users\elkfrawy\AppData\Local\Temp\ipykernel_8232\2317360568.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 3. Feature Engineering

# %%
# Create tenure buckets
df['Tenure_Bucket'] = pd.cut(
    df['YearsAtCompany'],
    bins=[0, 3, 7, 15, 40],
    labels=['0-3 years', '4-7 years', '8-15 years', '16+ years']
)

# %%
# Encode target variable
df['Attrition_Encoded'] = df['Attrition'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
# Interaction features
df['WorkLifeBalance_JobSatisfaction'] = df['WorkLifeBalance'] * df['JobSatisfaction']
df['WorkLifeBalance_JobSatisfaction']
# Out:
# 0        4.0
# 1        6.0
# 2        9.0
# 3        9.0
# 4        6.0
#         ...
# 1465    12.0
# 1466    12.0
# 1467     6.0
# 1468     4.0
# 1469    12.0
# Name: WorkLifeBalance_JobSatisfaction, Length: 1470, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ### 4. Univariate and Multivariate Analysis

# %%
# Univariate Analysis
sns.countplot(data=df, x='Attrition')
plt.title('Attrition Distribution')
plt.show()

# %%
# Numerical feature distributions
sns.histplot(df['MonthlyIncome'], kde=True)
plt.title('Monthly Income Distribution')
plt.show()

# %%
# Pairwise relationships
features = [
    'Age', 'YearsAtCompany', 'TotalWorkingYears', 'MonthlyIncome',
    'YearsInCurrentRole', 'JobSatisfaction', 'Attrition']
sns.set_theme(style="whitegrid", palette="muted")
sns.pairplot(df[features], 
             hue='Attrition', 
             diag_kind='kde', 
             markers=["o", "s"], 
             plot_kws={'alpha': 0.7, 's': 50})
plt.suptitle("Pairplot of Employee Attrition", size=16, y=1.02)
plt.show()

# %%
effective_features = ['Age', 'MonthlyIncome', 'YearsAtCompany', 'JobSatisfaction', 'YearsInCurrentRole']

correlation_matrix = df[effective_features].corr(numeric_only=True)

plt.figure(figsize=(8, 6))

sns.heatmap(correlation_matrix, 
            annot=True, 
            fmt=".2f", 
            cmap="coolwarm", 
            vmin=-1, vmax=1, 
            linewidths=0.5, 
            cbar_kws={'shrink': 0.8}, 
            annot_kws={"size": 14, "weight": "bold", "color": "white"})

plt.title("Correlation Heatmap", fontsize=18)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(rotation=0, fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 5. Insights Worth Mentioning

# %%
# Grouping by department and attrition
dept_attrition = df.groupby(['Department', 'Attrition']).size().unstack()
dept_attrition
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
# Pivot table for average income by department and attrition
pivot_table = df.pivot_table(
    values='MonthlyIncome',
    index='Department',
    columns='Attrition',
    aggfunc='mean'
)
pivot_table
# Out:
# Attrition                        No          Yes
# Department
# Human Resources         7894.274651  3715.750000
# Research & Development  6601.494968  4513.020602
# Sales                   7155.180556  6094.358852

# %%
sns.heatmap(pivot_table, cmap="Blues")
plt.title("Average Monthly Income by Department and Attrition")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 6. Outlier Detection and Handling

# %%
# Outlier detection using IQR (Interquartile Range)
Q1 = df['MonthlyIncome'].quantile(0.25)
Q3 = df['MonthlyIncome'].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
outliers = df[
    (df['MonthlyIncome'] < Q1 - 1.5 * IQR) |
    (df['MonthlyIncome'] > Q3 + 1.5 * IQR)
]
outliers
# Out:
#        Age Attrition     BusinessTravel  DailyRate              Department  \
# 18    53.0        No      Travel_Rarely       1219                   Sales
# 25    53.0        No      Travel_Rarely       1282  Research & Development
# 29    36.0        No      Travel_Rarely        705                   Sales
# 55    33.0        No  Travel_Frequently        515  Research & Development
# 62    50.0        No      Travel_Rarely        989  Research & Development
# ...    ...       ...                ...        ...                     ...
# 1403  36.0        No      Travel_Rarely        119                   Sales
# 1430  38.0        No      Travel_Rarely        201  Research & Development
# 1437  39.0        No         Non-Travel        105  Research & Development
# 1443  42.0        No      Travel_Rarely        300  Research & Development
# 1445  41.0        No      Travel_Rarely        582  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# Visualize outliers
sns.boxplot(data=df, x='Attrition', y='MonthlyIncome')
plt.title('Monthly Income by Attrition')
plt.show()

# %%
# Remove outliers
data_cleaned = df[
    (df['MonthlyIncome'] >= Q1 - 1.5 * IQR) &
    (df['MonthlyIncome'] <= Q3 + 1.5 * IQR)
]

# %% [markdown]
# ---

# %% [markdown]
# ### 7. Deeper Visualization

# %%
# Attrition by job role
sns.countplot(data=df, x='JobRole', hue='Attrition')
plt.xticks(rotation=45)
plt.title('Attrition by Job Role')
plt.show()

# %%
# Income by Attrition
sns.violinplot(data=df, x='Attrition', y='MonthlyIncome')
plt.title('Income Distribution by Attrition')
plt.show()

# %%
# Work-Life Balance
sns.kdeplot(data=df, x='WorkLifeBalance', hue='Attrition', fill=True)
plt.title('Work-Life Balance KDE by Attrition')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 8. Save Cleaned Data For ML Applications

# %%
data_cleaned.to_csv("Cleaned Data\employee_attrition_cleaned.csv", index=False)
print("Cleaned dataset saved as 'employee_attrition_cleaned.csv'")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\e'
# <>:1: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\elkfrawy\AppData\Local\Temp\ipykernel_8232\2381551699.py:1: SyntaxWarning: invalid escape sequence '\e'
#   data_cleaned.to_csv("Cleaned Data\employee_attrition_cleaned.csv", index=False)
# Cleaned dataset saved as 'employee_attrition_cleaned.csv'
